# %%
#Problem Statement: Student Data Management Using Python Collections
#List of student:
students={201:["Harshil","CSE core","89"],
          202:["Rahul","IT","77"],
          203:["Riya","CSE AIDS","80"]}
print("original student records:")
print(students)
#deletion of existing record:
del students[203]
#updating details of student:
students[202][0]= "Reah"
print("final student records")
print(students)
